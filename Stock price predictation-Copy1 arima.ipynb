# %%
#!pip install pandas_datareader

# %%
import pandas_datareader as pdr
import pandas as pd 
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Tata_data=pdr.get_data_yahoo('TTM')
Tata_data
# Out:
#                  High        Low       Open      Close   Volume  Adj Close
# Date
# 2017-05-31  36.970001  36.630001  36.849998  36.830002   898900  36.830002
# 2017-06-01  37.349998  36.910000  37.000000  37.119999   736500  37.119999
# 2017-06-02  37.380001  37.040001  37.139999  37.310001   669400  37.310001
# 2017-06-05  37.360001  36.869999  37.220001  37.000000   774800  37.000000
# 2017-06-06  35.910000  35.480000  35.910000  35.849998  1748200  35.849998
# ...               ...        ...        ...        ...      ...        ...
# 2022-05-23  27.650000  26.820000  27.030001  27.379999   587400  27.379999
# 2022-05-24  27.440001  26.860001  27.170000  27.260000   731100  27.260000
# 2022-05-25  27.459999  26.600000  26.719999  27.240000   792900  27.240000
# 2022-05-26  28.270000  27.290001  27.290001  28.010000   719200  28.010000
# 2022-05-27  28.219999  27.900000  28.020000  28.190001   700500  28.190001
#
# [1259 rows x 6 columns]

# %%
Tata_data.shape
# Out:
# (1259, 6)

# %%
Tata_data.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean     19.390127    18.995592    19.199380    19.196966  1.678551e+06
# std       9.310497     9.181998     9.245580     9.245695  9.829340e+05
# min       4.240000     3.920000     4.200000     4.080000  0.000000e+00
# 25%      11.740000    11.480000    11.600000    11.625000  9.938500e+05
# 50%      19.010000    18.620001    18.780001    18.840000  1.430400e+06
# 75%      28.304999    27.590000    27.970000    28.025001  2.058050e+06
# max      37.380001    37.040001    37.220001    37.310001  7.612300e+06
#
#          Adj Close
# count  1259.000000
# mean     19.196966
# std       9.245695
# min       4.080000
# 25%      11.625000
# 50%      18.840000
# 75%      28.025001
# max      37.310001

# %%
Tata_data.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %%
Tata_data.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
Tata_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2017-05-31 to 2022-05-27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1259 non-null   float64
#  1   Low        1259 non-null   float64
#  2   Open       1259 non-null   float64
#  3   Close      1259 non-null   float64
#  4   Volume     1259 non-null   int64
#  5   Adj Close  1259 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 68.9 KB

# %%
Tata_data.plot(figsize=(8,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data['High'].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data[['Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data['Open'].plot(xlim=['2018-01-01','2022-05-24'],ylim=[0,50],figsize=(6,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data['Close'].plot(xlim=['2018-01-01','2022-05-24'],ylim=[0,50],figsize=(6,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data['High'].plot(xlim=['2018-01-01','2022-05-24'],ylim=[0,50],figsize=(6,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data['Low'].plot(xlim=['2018-01-01','2022-05-24'],ylim=[0,50],figsize=(6,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data['High'].plot(xlim=['2018-01-01','2022-05-24'],ylim=[0,50],figsize=(6,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data.index
# Out:
# DatetimeIndex(['2017-05-31', '2017-06-01', '2017-06-02', '2017-06-05',
#                '2017-06-06', '2017-06-07', '2017-06-08', '2017-06-09',
#                '2017-06-12', '2017-06-13',
#                ...
#                '2022-05-16', '2022-05-17', '2022-05-18', '2022-05-19',
#                '2022-05-20', '2022-05-23', '2022-05-24', '2022-05-25',
#                '2022-05-26', '2022-05-27'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
index_open=Tata_data.loc['2017-05-24':'2022-05-24'].index
share_Open = Tata_data.loc['2017-05-24':'2022-05-24']['Open']
share_Open
# Out:
# Date
# 2017-05-31    36.849998
# 2017-06-01    37.000000
# 2017-06-02    37.139999
# 2017-06-05    37.220001
# 2017-06-06    35.910000
#                 ...
# 2022-05-18    26.809999
# 2022-05-19    25.670000
# 2022-05-20    26.969999
# 2022-05-23    27.030001
# 2022-05-24    27.170000
# Name: Open, Length: 1256, dtype: float64

# %%
index_close=Tata_data.loc['2017-05-24':'2022-05-24'].index
share_Close = Tata_data.loc['2017-05-24':'2022-05-24']['Close']
share_Close
# Out:
# Date
# 2017-05-31    36.830002
# 2017-06-01    37.119999
# 2017-06-02    37.310001
# 2017-06-05    37.000000
# 2017-06-06    35.849998
#                 ...
# 2022-05-18    26.110001
# 2022-05-19    26.010000
# 2022-05-20    26.760000
# 2022-05-23    27.379999
# 2022-05-24    27.260000
# Name: Close, Length: 1256, dtype: float64

# %%
index_open
# Out:
# DatetimeIndex(['2017-05-31', '2017-06-01', '2017-06-02', '2017-06-05',
#                '2017-06-06', '2017-06-07', '2017-06-08', '2017-06-09',
#                '2017-06-12', '2017-06-13',
#                ...
#                '2022-05-11', '2022-05-12', '2022-05-13', '2022-05-16',
#                '2022-05-17', '2022-05-18', '2022-05-19', '2022-05-20',
#                '2022-05-23', '2022-05-24'],
#               dtype='datetime64[ns]', name='Date', length=1256, freq=None)

# %%
index_close
# Out:
# DatetimeIndex(['2017-05-31', '2017-06-01', '2017-06-02', '2017-06-05',
#                '2017-06-06', '2017-06-07', '2017-06-08', '2017-06-09',
#                '2017-06-12', '2017-06-13',
#                ...
#                '2022-05-11', '2022-05-12', '2022-05-13', '2022-05-16',
#                '2022-05-17', '2022-05-18', '2022-05-19', '2022-05-20',
#                '2022-05-23', '2022-05-24'],
#               dtype='datetime64[ns]', name='Date', length=1256, freq=None)

# %%
figure,axis=plt.subplots()
plt.tight_layout()
axis.plot(index_open,share_Open)

# %%
figure,axis=plt.subplots()
plt.tight_layout()
axis.plot(index_close,share_Close)

# %%
Tata_data1=Tata_data.reset_index()
Tata_data1
# Out:
#            Date       High        Low       Open      Close   Volume  \
# 0    2017-05-31  36.970001  36.630001  36.849998  36.830002   898900
# 1    2017-06-01  37.349998  36.910000  37.000000  37.119999   736500
# 2    2017-06-02  37.380001  37.040001  37.139999  37.310001   669400
# 3    2017-06-05  37.360001  36.869999  37.220001  37.000000   774800
# 4    2017-06-06  35.910000  35.480000  35.910000  35.849998  1748200
# ...         ...        ...        ...        ...        ...      ...
# 1254 2022-05-23  27.650000  26.820000  27.030001  27.379999   587400
# 1255 2022-05-24  27.440001  26.860001  27.170000  27.260000   731100
# 1256 2022-05-25  27.459999  26.600000  26.719999  27.240000   792900
# 1257 2022-05-26  28.270000  27.290001  27.290001  28.010000   719200
# 1258 2022-05-27  28.219999  27.900000  28.020000  28.190001   700500
#
#       Adj Close
# 0     36.830002
# 1     37.119999
# 2     37.310001
# 3     37.000000
# 4     35.849998
# ...         ...
# ...

# %%
Tata_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   High       1259 non-null   float64
#  2   Low        1259 non-null   float64
#  3   Open       1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Volume     1259 non-null   int64
#  6   Adj Close  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.0 KB

# %%
Tata_data1.shape
# Out:
# (1259, 7)

# %%
Tata_data.resample(rule='A').min() # A=End of year
# Out:
#                  High        Low   Open      Close  Volume  Adj Close
# Date
# 2017-12-31  29.389999  28.969999  29.17  29.030001  417100  29.030001
# 2018-12-31  10.830000  10.490000  10.81  10.670000  411200  10.670000
# 2019-12-31   7.680000   7.380000   7.52   7.610000       0   7.610000
# 2020-12-31   4.240000   3.920000   4.20   4.080000  645700   4.080000
# 2021-12-31  13.150000  12.670000  12.93  12.760000  346900  12.760000
# 2022-12-31  24.389999  22.920000  23.85  24.120001  329900  24.120001

# %%
Tata_data.resample(rule='A').min()['Open'] .plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data.resample(rule='A').min()['Close'] .plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data.resample(rule='A').max()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close
# Date
# 2017
plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tata_data
# Out:
#                  High        Low       Open      Close   Volume  Adj Close  \
# Date
# 2017-05-31  36.970001  36.630001  36.849998  36.830002   898900  36.830002
# 2017-06-01  37.349998  36.910000  37.000000  37.119999   736500  37.119999
# 2017-06-02  37.380001  37.040001  37.139999  37.310001   669400  37.310001
# 2017-06-05  37.360001  36.869999  37.220001  37.000000   774800  37.000000
# 2017-06-06  35.910000  35.480000  35.910000  35.849998  1748200  35.849998
# ...               ...        ...        ...        ...      ...        ...
# 2022-05-23  27.650000  26.820000  27.030001  27.379999   587400  27.379999
# 2022-05-24  27.440001  26.860001  27.170000  27.260000   731100  27.260000
# 2022-05-25  27.459999  26.600000  26.719999  27.240000   792900  27.240000
# 2022-05-26  28.270000  27.290001  27.290001  28.010000   719200  28.010000
# 2022-05-27  28.219999  27.900000  28.020000  28.190001   700500  28.190001
#
#             Open:30 days rolling
# Date
# ...

# %%
data = Tata_data.reset_index()

# %%
data
# Out:
#            Date       High        Low       Open      Close   Volume  \
# 0    2017-05-31  36.970001  36.630001  36.849998  36.830002   898900
# 1    2017-06-01  37.349998  36.910000  37.000000  37.119999   736500
# 2    2017-06-02  37.380001  37.040001  37.139999  37.310001   669400
# 3    2017-06-05  37.360001  36.869999  37.220001  37.000000   774800
# 4    2017-06-06  35.910000  35.480000  35.910000  35.849998  1748200
# ...         ...        ...        ...        ...        ...      ...
# 1254 2022-05-23  27.650000  26.820000  27.030001  27.379999   587400
# 1255 2022-05-24  27.440001  26.860001  27.170000  27.260000   731100
# 1256 2022-05-25  27.459999  26.600000  26.719999  27.240000   792900
# 1257 2022-05-26  28.270000  27.290001  27.290001  28.010000   719200
# 1258 2022-05-27  28.219999  27.900000  28.020000  28.190001   700500
#
#       Adj Close  Open:30 days rolling
# 0     36.830002                   NaN
# 1     37.119999                   NaN
# ...

# %%
data = data.iloc[:,[0,3]]

# %%
data = data.reset_index()

# %%
data['index'] = data['index'] +1
data = data.rename(columns={'index':'t'})

# %%
import seaborn as sns
plt.figure(figsize=(12,4))
sns.lineplot(x='Date',y='Open',data=data)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
#for exponential model 
import numpy as np
data['log_Open'] = np.log(data['Open'])

# %%
data
# Out:
#          t       Date       Open  log_Open
# 0        1 2017-05-31  36.849998  3.606856
# 1        2 2017-06-01  37.000000  3.610918
# 2        3 2017-06-02  37.139999  3.614695
# 3        4 2017-06-05  37.220001  3.616846
# 4        5 2017-06-06  35.910000  3.581016
# ...    ...        ...        ...       ...
# 1254  1255 2022-05-23  27.030001  3.296947
# 1255  1256 2022-05-24  27.170000  3.302113
# 1256  1257 2022-05-25  26.719999  3.285412
# 1257  1258 2022-05-26  27.290001  3.306520
# 1258  1259 2022-05-27  28.020000  3.332919
#
# [1259 rows x 4 columns]

# %% [markdown]
# # Time series decomposition plot

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
se_dec = seasonal_decompose(data.Open,period=12)
se_dec.plot()
plt.show()

# %%
#check statinarity
from statsmodels.tsa.stattools import adfuller
test_result = adfuller(data['Open'])
print('ADF Statistic: %f' % test_result[0])
print('p-value: %f' % test_result[1])
if test_result[1] >= 0.05:
    print("the data is stationary")
else : print("data is not statinary")
# Out:
# ADF Statistic: -1.607685
# p-value: 0.479732
# the data is stationary

# %% [markdown]
# The null hypothesis of the ADF test is that the time series is non-stationary. So, if the p-value of the test is less than
# the significance level (0.05) then you reject the null hypothesis and infer that the time series is indeed stationary

# %%
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(data.Open); axes[0, 0].set_title('Original Series')
plot_acf(data.Open, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(data.Open.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(data.Open.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(data.Open.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(data.Open.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
model = pm.auto_arima(data.Open, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1926.889, Time=0.99 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1929.453, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1928.855, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1929.169, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1927.682, Time=0.36 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1924.242, Time=0.91 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1925.263, Time=0.18 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1926.084, Time=0.74 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1919.185, Time=1.77 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1923.781, Time=0.47 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1921.148, Time=1.58 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1921.155, Time=1.81 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1925.432, Time=0.71 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=1919.728, Time=2.29 sec
# ...

# %%
Tata_data
# Out:
#                  High        Low       Open      Close   Volume  Adj Close  \
# Date
# 2017-05-31  36.970001  36.630001  36.849998  36.830002   898900  36.830002
# 2017-06-01  37.349998  36.910000  37.000000  37.119999   736500  37.119999
# 2017-06-02  37.380001  37.040001  37.139999  37.310001   669400  37.310001
# 2017-06-05  37.360001  36.869999  37.220001  37.000000   774800  37.000000
# 2017-06-06  35.910000  35.480000  35.910000  35.849998  1748200  35.849998
# ...               ...        ...        ...        ...      ...        ...
# 2022-05-23  27.650000  26.820000  27.030001  27.379999   587400  27.379999
# 2022-05-24  27.440001  26.860001  27.170000  27.260000   731100  27.260000
# 2022-05-25  27.459999  26.600000  26.719999  27.240000   792900  27.240000
# 2022-05-26  28.270000  27.290001  27.290001  28.010000   719200  28.010000
# 2022-05-27  28.219999  27.900000  28.020000  28.190001   700500  28.190001
#
#             Open:30 days rolling
# Date
# ...

# %%
df =Tata_data.iloc[:,[2]]
df.info()
Train = df.iloc[1000:1230,:]
Test = df.tail(30)
print(Train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2017-05-31 to 2022-05-27
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1259 non-null   float64
# dtypes: float64(1)
# memory usage: 52.0 KB
#                  Open
# Date
# 2021-05-20  20.930000
# 2021-05-21  21.230000
# 2021-05-24  21.270000
# 2021-05-25  21.580000
# 2021-05-26  21.459999
# ...               ...
# 2022-04-11  29.570000
# 2022-04-12  28.870001
# 2022-04-13  28.049999
# 2022-04-14  27.910000
# 2022-04-18  27.920000
#
# [230 rows x 1 columns]

# %%
# Build Model
# model = ARIMA(train, order=(3,2,1))  
model = ARIMA(Train, order=(0,1,2))  
fitted = model.fit(disp=-1)  

# Forecast
fc, se, conf = fitted.forecast(30, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=Test.index)
lower_series = pd.Series(conf[:, 0], index=Test.index)
upper_series = pd.Series(conf[:, 1], index=Test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(Train, label='training')
plt.plot(Test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\91960\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...
